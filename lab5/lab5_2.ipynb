# %%
# !git clone https://github.com/thunlp/OpenNRE.git --depth 1
# Out:
# Cloning into 'OpenNRE'...
# remote: Enumerating objects: 69, done.
# remote: Counting objects: 100% (69/69), done.
# remote: Compressing objects: 100% (58/58), done.
# remote: Total 69 (delta 21), reused 33 (delta 10), pack-reused 0 (from 0)
# Receiving objects: 100% (69/69), 46.54 KiB | 567.00 KiB/s, done.
# Resolving deltas: 100% (21/21), done.

# %%
# %cd OpenNRE
# Out:
# /content/OpenNRE

# %%
# !pip install numpy transformers pytest scikit-learn scipy nltk

# %%
# !python setup.py install
# Out:
# /usr/local/lib/python3.11/dist-packages/setuptools/__init__.py:94: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
# !!
#
#         ********************************************************************************
#         Requirements should be satisfied by a PEP 517 installer.
#         If you are using pip, you can try `pip install --use-pep517`.
#         ********************************************************************************
#
# !!
#   dist.fetch_build_eggs(dist.setup_requires)
# running install
# /usr/local/lib/python3.11/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
# ...

# %%
# !chmod +x ./benchmark/download_nyt10m.sh
# !./benchmark/download_nyt10m.sh
# Out:
# mkdir: cannot create directory ‘nyt10m’: File exists
# --2025-04-01 02:35:17--  https://thunlp.oss-cn-qingdao.aliyuncs.com/opennre/benchmark/nyt10m/nyt10m_rel2id.json
# Resolving thunlp.oss-cn-qingdao.aliyuncs.com (thunlp.oss-cn-qingdao.aliyuncs.com)... 47.104.38.189
# Connecting to thunlp.oss-cn-qingdao.aliyuncs.com (thunlp.oss-cn-qingdao.aliyuncs.com)|47.104.38.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 902 [application/json]
# Saving to: ‘nyt10m/nyt10m_rel2id.json.1’
#
# nyt10m_rel2id.json. 100%[===================>]     902  --.-KB/s    in 0s
#
# 2025-04-01 02:35:18 (548 MB/s) - ‘nyt10m/nyt10m_rel2id.json.1’ saved [902/902]
#
# --2025-04-01 02:35:18--  https://thunlp.oss-cn-qingdao.aliyuncs.com/opennre/benchmark/nyt10m/nyt10m_train.txt
# Resolving thunlp.oss-cn-qingdao.aliyuncs.com (thunlp.oss-cn-qingdao.aliyuncs.com)... 47.104.38.189
# ...

# %%
# !python example/train_bag_cnn.py \
    --metric auc \
    --dataset nyt10m \
    --batch_size 160 \
    --lr 0.1 \
    --weight_decay 1e-5 \
    --max_epoch 10 \
    --max_length 128 \
    --seed 42 \
    --encoder cnn \
    --aggr att
# Out:
# 2025-04-01 02:35:47.048534: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743474947.069889    6870 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743474947.076496    6870 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-01 02:35:47.098954: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python example/train_bag_cnn.py \
    --metric auc \
    --dataset nyt10m \
    --batch_size 160 \
    --lr 0.1 \
    --weight_decay 1e-5 \
    --max_epoch 10 \
    --max_length 128 \
    --seed 42 \
    --encoder cnn \
    --aggr avg
# Out:
# 2025-04-01 05:51:06.810051: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743486666.831046     811 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743486666.837293     811 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-01 05:51:06.858442: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
